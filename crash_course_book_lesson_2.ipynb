# %% [markdown]
# ## Strings

# %%
# method title 
name = "sandeep"
print(name.title())
# Out:
# Sandeep

# %%
print(name.upper())
# Out:
# SANDEEP

# %%
print(name.lower(), name.capitalize()) # there is also capitalize which only puts the first character uppercase. --jd, 
# what is differance between capitalize() vs title()? -- Sandeep
# Out:
# sandeep Sandeep

# %%
'jd browne'.title(), 'jd browne'.capitalize()
# Out:
# ('Jd Browne', 'Jd browne')

# %% [markdown]
# ## Variables

# %%
first_name = "John"
last_name = "Smith"

print(f"Hello {first_name} {last_name}!")
# Out:
# Hello John Smith!

# %%
print('\tPython')
# Out:
# 	Python

# %%
print("Languages: \n\tPython\n\tC\n\tJava")
# Out:
# Languages:
# 	Python
# 	C
# 	Java

# %%
#rstrip method to remove whitespace from right side. Yes, my bad. It removes parmanently.
my_name = "Sandeep "
print("%r" % my_name)  # to be able to see the space in the string, you can use "%r" for "raw strings" --jd
# Out:
# 'Sandeep '

# %%
print(my_name.rstrip())
# Out:
# Sandeep

# %%
quote = 'Albert Einstein once said,"A person who never made a mistake never tried anything new."'
print(quote)
# Out:
# Albert Einstein once said,"A person who never made a mistake never tried anything new."

# %%
#exersices 2.5
quote = "Albert Einstein once said,\"A person who never made a mistake never tried anything new.\""
print(quote)
# Out:
# Albert Einstein once said,"A person who never made a mistake never tried anything new."

# %%
#exersices 2.6
famous_person = "Albert Einstein"
message = "A person who never made a mistake never tried anything new."

print(f"{famous_person} once said, \"{message}\"")
# Out:
# Albert Einstein once said, "A person who never made a mistake never tried anything new."

# %%
#exersices 2.7
person_name = " John Smith "
print("%r" % person_name)
# there two more methods, lstrip() and rstrip(). lstrip for leftside whitespace only and rstrip for rightside whitespace only  
person_name = person_name.strip()

print("%r" % person_name)
# Out:
# ' John Smith '
# 'John Smith'

# %%
doctor = " Raj"
#doctor = doctor.lstrip()
print("%r"%doctor.lstrip())

guest = " Lali"

print("%r"%guest.lstrip())
# Out:
# 'Raj'
# 'Lali'

# %% [markdown]
# ## Numbers

# %% [markdown]
# ### Integers

# %%
2 + 3
# Out:
# 5

# %%
2*3
# Out:
# 6

# %%
15-11
# Out:
# 4

# %%
3/2
# Out:
# 1.5

# %%
10**2
# Out:
# 100

# %%
4**4
# Out:
# 256

# %%
2+3*2
# Out:
# 8

# %%
(2+3)*2
# Out:
# 10

# %% [markdown]
# ### Floats

# %%
0.1+0.5
# Out:
# 0.6

# %%
0.3+0.5
# Out:
# 0.8

# %%
1.12-0.9
# Out:
# 0.22000000000000008

# %%
2*2.3
# Out:
# 4.6

# %%
10/1.5
# Out:
# 6.666666666666667

# %%
3.0**2
# Out:
# 9.0

# %% [markdown]
# ##Underscore in Numbers

# %%
value = 100_000_000
print(value)
# Out:
# 100000000

# %% [markdown]
# ##Multiple Assigment

# %%
x, y, z = 5,8,13
print(f"Values of {x}, {y}, {z} ")
# Out:
# Values of 5, 8, 13

# %% [markdown]
# ## Constants
# writing in capital letters is just a indication for other users that it is a constant value and never be changed

# %%
MAX_VALUE = 5000
print(MAX_VALUE)

MAX_VALUE += 2000
print(MAX_VALUE)

lowest_value = 200
print(lowest_value)
lowest_value += lowest_value
print(lowest_value)
# Out:
# 5000
# 7000
# 200
# 400

# %%
#exersices 2.8
print(4+4)
print(13-5)
print(4*2)
print(64/8)
print(64//8)  # there is also the integer division now, to make sure the result is an int, and not a float.
# Out:
# 8
# 8
# 8
# 8.0
# 8

# %%
#exersices 2.9
favorite_number = 7
message = "This is his favorite number: "
print(f"{message}{favorite_number}")
# Out:
# This is his favorite number: 7

# %% [markdown]
# ## Comments

# %%
#exersices 2.9
# In this exersice, there is a favorite number and a messege. 
#Output will show both
favorite_number = 7
message = "This is his favorite number: "
print(f"{message}{favorite_number}")

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
